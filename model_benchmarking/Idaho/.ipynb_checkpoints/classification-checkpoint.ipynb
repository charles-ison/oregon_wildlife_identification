# %%
import os
import torch
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
import shutil
import json
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
class image_data_set(torch.utils.data.Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
  
    def __len__(self):
        return len(self.data)
  
    def __getitem__(self, index):
        return {'data': self.data[index], 'label': self.labels[index]}

# %%
def download_data(folder_name, downloaded_data_dir, json_file_name):
    blob_name = "https://lilablobssc.blob.core.windows.net/idaho-camera-traps/"
    
    if not os.path.isdir(downloaded_data_dir + json_file_name):
        json_file_zip_name = json_file_name + ".zip"
        json_zip_to_download = blob_name + json_file_zip_name
        download_json_zip_command = "azcopy cp '%s' '%s'" % (json_zip_to_download, downloaded_data_dir)
        os.system(download_json_zip_command)
        shutil.unpack_archive(downloaded_data_dir + json_file_zip_name, downloaded_data_dir)
        os.remove(downloaded_data_dir + json_file_zip_name)
    else:
        print("Required json zip already downloaded")
    
    if not os.path.isdir(downloaded_data_dir + folder_name):
        folder_to_download = blob_name + "public/" + folder_name
        download_folder_command = "azcopy cp '%s' '%s' --recursive" % (folder_to_download, downloaded_data_dir)
        os.system(download_folder_command)
    else:
        print("Required folder already downloaded")

# %%
def get_image_tensor(file_path):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    
    image = Image.open(file_path)
    return transform(image)
    
def get_data_sets(folder_name, downloaded_data_dir, json_file_name, categories_to_label_dict): 
    json_file = open(downloaded_data_dir + json_file_name)
    coco_key = json.load(json_file)
    images = coco_key["images"]

    data, labels = [], []
    for index, image in enumerate(images):
        file_name = image["file_name"]
        file_path = downloaded_data_dir + file_name
        
        if file_name.startswith(folder_name) and os.path.isfile(file_path):
            category_id = coco_key["annotations"][index]["category_id"]
            label = categories_to_label_dict[category_id]
            image_tensor = get_image_tensor(file_path)
            data.append(image_tensor)
            labels.append(label)
            print("Preparing image number: " + str(index))
    
    training_data, testing_data, training_labels, testing_labels = train_test_split(data, labels)
    
    print("\nNumber of training photos: " + str(len(training_data)))
    print("Number of testing photos: " + str(len(testing_data)))
    
    training_data_set = image_data_set(training_data, training_labels)
    testing_data_set = image_data_set(testing_data, testing_labels)
    
    json_file.close()
    
    shutil.rmtree(downloaded_data_dir + folder_name)
    os.remove(downloaded_data_dir + json_file_name)
    
    return training_data_set, testing_data_set

def get_loaders(training_data_set, testing_data_set, batch_size):
    training_loader = torch.utils.data.DataLoader(dataset = training_data_set,
                                                  batch_size = batch_size,
                                                  shuffle = True)

    testing_loader = torch.utils.data.DataLoader(dataset = testing_data_set,
                                                 batch_size = batch_size,
                                                 shuffle = True)
    
    return training_loader, testing_loader

# %%
def print_image(image_tensor, prediction):
    if(prediction == 1):
        prediction_string = "Wildlife Present"
    else:
        prediction_string = "No Wildlife Present"

    #Alternative normalized RGB visualization: plt.imshow(image_tensor.cpu().permute(1, 2, 0).numpy())
    plt.imshow(image_tensor[0].cpu(), cmap="gray")
    plt.title("Incorrectly Predicted " + prediction_string) 
    plt.show()

def print_testing_analysis(all_labels, all_predictions, title):
    subplot = plt.subplot()

    cf_matrix = confusion_matrix(all_labels, all_predictions, labels=[1, 0])
    sns.heatmap(cf_matrix, annot=True, fmt='g', cmap='Blues')

    subplot.set_xlabel('Predictions')
    subplot.set_ylabel('Labels')
    subplot.set_title(title + ' Testing Confusion Matrix')
    subplot.xaxis.set_ticklabels(['Wildlife Present', 'No Wildlife Present'])
    subplot.yaxis.set_ticklabels(['Wildlife Present', 'No Wildlife Present'])
    plt.show()

    accuracy = accuracy_score(all_labels, all_predictions)
    print(title + " Accuracy: " + str(accuracy))

    precision, recall, f_score, support = precision_recall_fscore_support(all_labels, all_predictions, average='binary')
    print(title + " Precision: " + str(precision))
    print(title + " Recall: " + str(recall))
    print(title + " F-Score: " + str(f_score))

def train(model, training_loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    num_correct = 0
    for i, data in enumerate(training_loader):
        print("batch number: " + str(i))
        data, labels = data['data'].to(device), data['label'].to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, labels)
        running_loss += loss.item()
        _, predictions = torch.max(output.data, 1)
        num_correct += (predictions == labels).sum().item()
        loss.backward()
        optimizer.step()
    
    loss = running_loss/len(training_loader.dataset)
    accuracy = num_correct/len(training_loader.dataset)
    return loss, accuracy

def test(model, testing_loader, criterion, print_incorrect_images):
    model.eval()
    running_loss = 0.0
    num_correct = 0
    all_labels, all_predictions = [], []

    for i, data in enumerate(testing_loader):
        data, labels = data['data'].to(device), data['label'].to(device)
        output = model(data)
        loss = criterion(output, labels)
        running_loss += loss.item()
        _, predictions = torch.max(output.data, 1)
        for index, prediction in enumerate(predictions):
            if(prediction == labels[index]):
                num_correct += 1
            elif(print_incorrect_images):
                print_image(data[index], prediction)

        all_labels.extend(labels.cpu())
        all_predictions.extend(predictions.cpu())
    
    loss = running_loss/len(testing_loader.dataset)
    accuracy = num_correct/len(testing_loader.dataset)
    return loss, accuracy, all_labels, all_predictions

# %%
def train_and_test(model, training_loader, testing_loader, device):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
    
    for epoch in range(10):
        print("epoch: " + str(epoch))
        
        training_loss, training_accuracy = train(model, training_loader, criterion, optimizer)
        print("training loss: " + str(training_loss) + " and training accuracy: " + str(training_accuracy))
        
        testing_loss, testing_accuracy, _, _ = test(model, testing_loader, criterion, False)
        print("testing loss: " + str(testing_loss) + " and testing accuracy: " + str(testing_accuracy))

    testing_loss, testing_accuracy, labels, predictions = test(model, testing_loader, criterion, True)
    print_testing_analysis(labels, predictions, "Overall")

# %%
def train_and_test_ResNet50(training_loader, testing_loader, device, num_classes):
    print("\nTraining and Testing ResNet50")
    resnet50 = models.resnet50(weights = models.ResNet50_Weights.DEFAULT)
    resnet50.fc.out_features = num_classes
    train_and_test(resnet50, training_loader, testing_loader, device)

def train_and_test_ResNet152(training_loader, testing_loader, device, num_classes):
    print("\nTraining and Testing ResNet152")
    resnet152 = models.resnet152(weights = models.ResNet152_Weights.DEFAULT)
    resnet152.fc.out_features = num_classes
    train_and_test(resnet152, training_loader, testing_loader, device)

def train_and_test_ViT_L_16(training_loader, testing_loader, device, num_classes):
    print("\nTraining and Testing Vision Transformer Large 16")
    vit_l_16 = models.vit_l_16(weights = models.ViT_L_16_Weights.DEFAULT)
    vit_l_16.heads.out_features = num_classes
    train_and_test(vit_l_16, training_loader, testing_loader, device)

# %% [markdown]
# # Orchestration

# %%
num_classes = 2
batch_size = 10
json_file_name = "idaho-camera-traps.json"

#TODO: add loop here
folder_name = "loc_0000"
downloaded_data_folder = "downloaded_data/"

# Mapping canines, big cats, bears, and ungulates to wildlife present and all other categories to no wildlife present
# This is mostly arbitrary and could be reworked, we just need to draw the line somewhere
categories_to_label_dict = {
    0:0, 1:0, 2:0, 3:1, 4:0, 5:1, 6:1, 7:0, 8:0, 9:1, 
    10:1, 11:0, 12:1, 13:1, 14:0, 15:0, 16:1, 17:0, 18:1, 19:0,
    20:1, 21:0, 22:1, 23:0, 24:1, 25:0, 26:0, 27:0, 28:0, 29:0,
    30:0, 31:0, 32:0, 33:0, 34:0, 35:0, 36:0, 37:0, 38:1, 39:1,
    40:1, 41:0, 42:0, 43:0, 44:0, 45:1, 46:0, 47:0, 48:1, 49:0,
    50:0, 51:0, 52:0, 53:0, 54:0, 55:0, 56:0, 57:0, 58:0, 59:0,
    60:0, 61:0,
}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.cuda.empty_cache()

# %%
download_data(folder_name, downloaded_data_folder, json_file_name)
# Out:
# INFO: Scanning...
# INFO: azcopy: A newer version 10.18.0 is available to download
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 8e09000a-766a-4d4f-7630-7a16b4b780ad has started
# Log file is located at: /Users/ChaseIson 1/.azcopy/8e09000a-766a-4d4f-7630-7a16b4b780ad.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total,
#
#
# Job 8e09000a-766a-4d4f-7630-7a16b4b780ad summary
# Elapsed Time (Minutes): 0.2001
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Total Number of Transfers: 1
# Number of Transfers Completed: 1
# Number of Transfers Failed: 0
# Number of Transfers Skipped: 0
# TotalBytesTransferred: 26765533
# Final Job Status: Completed
#
# INFO: Scanning...
# INFO: azcopy: A newer version 10.18.0 is available to download
#
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 58690a0c-c76d-e840-5210-74f57342782f has started
# Log file is located at: /Users/ChaseIson 1/.azcopy/58690a0c-c76d-e840-5210-74f57342782f.log
#
# 100.0 %, 13083 Done, 0 Failed, 0 Pending, 0 Skipped, 13083 Total,
#
#
# Job 58690a0c-c76d-e840-5210-74f57342782f summary
# Elapsed Time (Minutes): 4.1347
# Number of File Transfers: 13083
# Number of Folder Property Transfers: 0
# Total Number of Transfers: 13083
# Number of Transfers Completed: 13083
# Number of Transfers Failed: 0
# Number of Transfers Skipped: 0
# TotalBytesTransferred: 4064614147
# Final Job Status: Completed

# %%
training_data_set, testing_data_set = get_data_sets(folder_name, downloaded_data_folder, json_file_name, categories_to_label_dict)
training_loader, testing_loader = get_loaders(training_data_set, testing_data_set, batch_size)
# Out:
# Preparing image number: 0
# Preparing image number: 1
# Preparing image number: 2
# Preparing image number: 3
# Preparing image number: 4
# Preparing image number: 5
# Preparing image number: 6
# Preparing image number: 7
# Preparing image number: 8
# Preparing image number: 9
# Preparing image number: 10
# Preparing image number: 11
# Preparing image number: 12
# Preparing image number: 13
# Preparing image number: 14
# Preparing image number: 15
# Preparing image number: 16
# Preparing image number: 17
# Preparing image number: 18
# Preparing image number: 19
# Preparing image number: 20
# Preparing image number: 21
# Preparing image number: 22
# Preparing image number: 23
# Preparing image number: 24
# Preparing image number: 25
# Preparing image number: 26
# Preparing image number: 27
# Preparing image number: 28
# Preparing image number: 29
# Preparing image number: 30
# Preparing image number: 31
# Preparing image number: 32
# Preparing image number: 33
# Preparing image number: 34
# Preparing image number: 35
# Preparing image number: 36
# Preparing image number: 37
# Preparing image number: 38
# Preparing image number: 39
# Preparing image number: 40
# Preparing image number: 41
# Preparing image number: 42
# Preparing image number: 43
# Preparing image number: 44
# Preparing image number: 45
# Preparing image number: 46
# Preparing image number: 47
# Preparing image number: 48
# Preparing image number: 49
# Preparing image number: 50
# Preparing image number: 51
# Preparing image number: 52
# Preparing image number: 53
# Preparing image number: 54
# Preparing image number: 55
# Preparing image number: 56
# Preparing image number: 57
# Preparing image number: 58
# Preparing image number: 59
# Preparing image number: 60
# Preparing image number: 61
# Preparing image number: 62
# Preparing image number: 63
# Preparing image number: 64
# Preparing image number: 65
# Preparing image number: 66
# Preparing image number: 67
# Preparing image number: 68
# Preparing image number: 69
# Preparing image number: 70
# Preparing image number: 71
# Preparing image number: 72
# Preparing image number: 73
# Preparing image number: 74
# Preparing image number: 75
# Preparing image number: 76
# Preparing image number: 77
# Preparing image number: 78
# Preparing image number: 79
# Preparing image number: 80
# Preparing image number: 81
# Preparing image number: 82
# Preparing image number: 83
# Preparing image number: 84
# Preparing image number: 85
# Preparing image number: 86
# Preparing image number: 87
# Preparing image number: 88
# Preparing image number: 89
# Preparing image number: 90
# Preparing image number: 91
# Preparing image number: 92
# Preparing image number: 93
# Preparing image number: 94
# Preparing image number: 95
# Preparing image number: 96
# Preparing image number: 97
# Preparing image number: 98
# Preparing image number: 99
# Preparing image number: 100
# Preparing image number: 101
# Preparing image number: 102
# Preparing image number: 103
# Preparing image number: 104
# Preparing image number: 105
# Preparing image number: 106
# Preparing image number: 107
# Preparing image number: 108
# Preparing image number: 109
# Preparing image number: 110
# Preparing image number: 111
# Preparing image number: 112
# Preparing image number: 113
# Preparing image number: 114
# Preparing image number: 115
# Preparing image number: 116
# Preparing image number: 117
# Preparing image number: 118
# Preparing image number: 119
# Preparing image number: 120
# Preparing image number: 121
# Preparing image number: 122
# Preparing image number: 123
# Preparing image number: 124
# Preparing image number: 125
# Preparing image number: 126
# Preparing image number: 127
# Preparing image number: 128
# Preparing image number: 129
# Preparing image number: 130
# Preparing image number: 131
# Preparing image number: 132
# Preparing image number: 133
# Preparing image number: 134
# Preparing image number: 135
# Preparing image number: 136
# Preparing image number: 137
# Preparing image number: 138
# Preparing image number: 139
# Preparing image number: 140
# Preparing image number: 141
# Preparing image number: 142
# Preparing image number: 143
# Preparing image number: 144
# Preparing image number: 145
# Preparing image number: 146
# Preparing image number: 147
# Preparing image number: 148
# Preparing image number: 149
# Preparing image number: 150
# Preparing image number: 151
# Preparing image number: 152
# Preparing image number: 153
# Preparing image number: 154
# Preparing image number: 155
# Preparing image number: 156
# Preparing image number: 157
# Preparing image number: 158
# Preparing image number: 159
# Preparing image number: 160
# Preparing image number: 161
# Preparing image number: 162
# Preparing image number: 163
# Preparing image number: 164
# Preparing image number: 165
# Preparing image number: 166
# Preparing image number: 167
# Preparing image number: 168
# Preparing image number: 169
# Preparing image number: 170
# Preparing image number: 171
# Preparing image number: 172
# Preparing image number: 173
# Preparing image number: 174
# Preparing image number: 175
# Preparing image number: 176
# Preparing image number: 177
# Preparing image number: 178
# Preparing image number: 179
# Preparing image number: 180
# Preparing image number: 181
# Preparing image number: 182
# Preparing image number: 183
# Preparing image number: 184
# Preparing image number: 185
# Preparing image number: 186
# Preparing image number: 187
# Preparing image number: 188
# Preparing image number: 189
# Preparing image number: 190
# Preparing image number: 191
# Preparing image number: 192
# Preparing image number: 193
# Preparing image number: 194
# Preparing image number: 195
# Preparing image number: 196
# Preparing image number: 197
# Preparing image number: 198
# Preparing image number: 199
# Preparing image number: 200
# Preparing image number: 201
# Preparing image number: 202
# Preparing image number: 203
# Preparing image number: 204
# Preparing image number: 205
# Preparing image number: 206
# Preparing image number: 207
# Preparing image number: 208
# Preparing image number: 209
# Preparing image number: 210
# Preparing image number: 211
# Preparing image number: 212
# Preparing image number: 213
# Preparing image number: 214
# Preparing image number: 215
# Preparing image number: 216
# Preparing image number: 217
# Preparing image number: 218
# Preparing image number: 219
# Preparing image number: 220
# Preparing image number: 221
# Preparing image number: 222
# Preparing image number: 223
# Preparing image number: 224
# Preparing image number: 225
# Preparing image number: 226
# Preparing image number: 227
# Preparing image number: 228
# Preparing image number: 229
# Preparing image number: 230
# Preparing image number: 231
# Preparing image number: 232
# Preparing image number: 233
# Preparing image number: 234
# Preparing image number: 235
# Preparing image number: 236
# Preparing image number: 237
# Preparing image number: 238
# Preparing image number: 239
# Preparing image number: 240
# Preparing image number: 241
# Preparing image number: 242
# Preparing image number: 243
# Preparing image number: 244
# Preparing image number: 245
# Preparing image number: 246
# Preparing image number: 247
# Preparing image number: 248
# Preparing image number: 249
# Preparing image number: 250
# Preparing image number: 251
# Preparing image number: 252
# Preparing image number: 253
# Preparing image number: 254
# Preparing image number: 255
# Preparing image number: 256
# Preparing image number: 257
# Preparing image number: 258
# Preparing image number: 259
# Preparing image number: 260
# Preparing image number: 261
# Preparing image number: 262
# Preparing image number: 263
# Preparing image number: 264
# Preparing image number: 265
# Preparing image number: 266
# Preparing image number: 267
# Preparing image number: 268
# Preparing image number: 269
# Preparing image number: 270
# Preparing image number: 271
# Preparing image number: 272
# Preparing image number: 273
# Preparing image number: 274
# Preparing image number: 275
# Preparing image number: 276
# Preparing image number: 277
# Preparing image number: 278
# Preparing image number: 279
# Preparing image number: 280
# Preparing image number: 281
# Preparing image number: 282
# Preparing image number: 283
# Preparing image number: 284
# Preparing image number: 285
# Preparing image number: 286
# Preparing image number: 287
# Preparing image number: 288
# Preparing image number: 289
# Preparing image number: 290
# Preparing image number: 291
# Preparing image number: 292
# Preparing image number: 293
# Preparing image number: 294
# Preparing image number: 295
# Preparing image number: 296
# Preparing image number: 297
# Preparing image number: 298
# Preparing image number: 299
# Preparing image number: 300
# Preparing image number: 301
# Preparing image number: 302
# Preparing image number: 303
# Preparing image number: 304
# Preparing image number: 305
# Preparing image number: 306
# Preparing image number: 307
# Preparing image number: 308
# Preparing image number: 309
# Preparing image number: 310
# Preparing image number: 311
# Preparing image number: 312
# Preparing image number: 313
# Preparing image number: 314
# Preparing image number: 315
# Preparing image number: 316
# Preparing image number: 317
# Preparing image number: 318
# Preparing image number: 319
# Preparing image number: 320
# Preparing image number: 321
# Preparing image number: 322
# Preparing image number: 323
# Preparing image number: 324
# Preparing image number: 325
# Preparing image number: 326
# Preparing image number: 327
# Preparing image number: 328
# Preparing image number: 329
# Preparing image number: 330
# Preparing image number: 331
# Preparing image number: 332
# Preparing image number: 333
# Preparing image number: 334
# Preparing image number: 335
# Preparing image number: 336
# Preparing image number: 337
# Preparing image number: 338
# Preparing image number: 339
# Preparing image number: 340
# Preparing image number: 341
# Preparing image number: 342
# Preparing image number: 343
# Preparing image number: 344
# Preparing image number: 345
# Preparing image number: 346
# Preparing image number: 347
# Preparing image number: 348
# Preparing image number: 349
# Preparing image number: 350
# Preparing image number: 351
# Preparing image number: 352
# Preparing image number: 353
# Preparing image number: 354
# Preparing image number: 355
# Preparing image number: 356
# Preparing image number: 357
# Preparing image number: 358
# Preparing image number: 359
# Preparing image number: 360
# Preparing image number: 361
# Preparing image number: 362
# Preparing image number: 363
# Preparing image number: 364
# Preparing image number: 365
# Preparing image number: 366
# Preparing image number: 367
# Preparing image number: 368
# Preparing image number: 369
# Preparing image number: 370
# Preparing image number: 371
# Preparing image number: 372
# Preparing image number: 373
# Preparing image number: 374
# Preparing image number: 375
# Preparing image number: 376
# Preparing image number: 377
# Preparing image number: 378
# Preparing image number: 379
# Preparing image number: 380
# Preparing image number: 381
# Preparing image number: 382
# Preparing image number: 383
# Preparing image number: 384
# Preparing image number: 385
# Preparing image number: 386
# Preparing image number: 387
# Preparing image number: 388
# Preparing image number: 389
# Preparing image number: 390
# Preparing image number: 391
# Preparing image number: 392
# Preparing image number: 393
# Preparing image number: 394
# Preparing image number: 395
# Preparing image number: 396
# Preparing image number: 397
# Preparing image number: 398
# Preparing image number: 399
# Preparing image number: 400
# Preparing image number: 401
# Preparing image number: 402
# Preparing image number: 403
# Preparing image number: 404
# Preparing image number: 405
# Preparing image number: 406
# Preparing image number: 407
# Preparing image number: 408
# Preparing image number: 409
# Preparing image number: 410
# Preparing image number: 411
# Preparing image number: 412
# Preparing image number: 413
# Preparing image number: 414
# Preparing image number: 415
# Preparing image number: 416
# Preparing image number: 417
# Preparing image number: 418
# Preparing image number: 419
# Preparing image number: 420
# Preparing image number: 421
# Preparing image number: 422
# Preparing image number: 423
# Preparing image number: 424
# Preparing image number: 425
# Preparing image number: 426
# Preparing image number: 427
# Preparing image number: 428
# Preparing image number: 429
# Preparing image number: 430
# Preparing image number: 431
# Preparing image number: 432
# Preparing image number: 433
# Preparing image number: 434
# Preparing image number: 435
# Preparing image number: 436
# Preparing image number: 437
# Preparing image number: 438
# Preparing image number: 439
# Preparing image number: 440
# Preparing image number: 441
# Preparing image number: 442
# Preparing image number: 443
# Preparing image number: 444
# Preparing image number: 445
# Preparing image number: 446
# Preparing image number: 447
# Preparing image number: 448
# Preparing image number: 449
# Preparing image number: 450
# Preparing image number: 451
# Preparing image number: 452
# Preparing image number: 453
# Preparing image number: 454
# Preparing image number: 455
# Preparing image number: 456
# Preparing image number: 457
# Preparing image number: 458
# Preparing image number: 459
# Preparing image number: 460
# Preparing image number: 461
# Preparing image number: 462
# Preparing image number: 463
# Preparing image number: 464
# Preparing image number: 465
# Preparing image number: 466
# Preparing image number: 467
# Preparing image number: 468
# Preparing image number: 469
# Preparing image number: 470
# Preparing image number: 471
# Preparing image number: 472
# Preparing image number: 473
# Preparing image number: 474
# Preparing image number: 475
# Preparing image number: 476
# Preparing image number: 477
# Preparing image number: 478
# Preparing image number: 479
# Preparing image number: 480
# Preparing image number: 481
# Preparing image number: 482
# Preparing image number: 483
# Preparing image number: 484
# Preparing image number: 485
# Preparing image number: 486
# Preparing image number: 487
# Preparing image number: 488
# Preparing image number: 489
# Preparing image number: 490
# Preparing image number: 491
# Preparing image number: 492
# Preparing image number: 493
# Preparing image number: 494
# Preparing image number: 495
# Preparing image number: 496
# Preparing image number: 497
# Preparing image number: 498
# Preparing image number: 499
# Preparing image number: 500
# Preparing image number: 501
# Preparing image number: 502
# Preparing image number: 503
# Preparing image number: 504
# Preparing image number: 505
# Preparing image number: 506
# Preparing image number: 507
# Preparing image number: 508
# Preparing image number: 509
# Preparing image number: 510
# Preparing image number: 511
# Preparing image number: 512
# Preparing image number: 513
# Preparing image number: 514
# Preparing image number: 515
# Preparing image number: 516
# Preparing image number: 517
# Preparing image number: 518
# Preparing image number: 519
# Preparing image number: 520
# Preparing image number: 521
# Preparing image number: 522
# Preparing image number: 523
# Preparing image number: 524
# Preparing image number: 525
# Preparing image number: 526
# Preparing image number: 527
# Preparing image number: 528
# Preparing image number: 529
# Preparing image number: 530
# Preparing image number: 531
# Preparing image number: 532
# Preparing image number: 533
# Preparing image number: 534
# Preparing image number: 535
# Preparing image number: 536
# Preparing image number: 537
# Preparing image number: 538
# Preparing image number: 539
# Preparing image number: 540
# Preparing image number: 541
# Preparing image number: 542
# Preparing image number: 543
# Preparing image number: 544
# Preparing image number: 545
# Preparing image number: 546
# Preparing image number: 547
# Preparing image number: 548
# Preparing image number: 549
# Preparing image number: 550
# Preparing image number: 551
# Preparing image number: 552
# Preparing image number: 553
# Preparing image number: 554
# Preparing image number: 555
# Preparing image number: 556
# Preparing image number: 557
# Preparing image number: 558
# Preparing image number: 559
# Preparing image number: 560
# Preparing image number: 561
# Preparing image number: 562
# Preparing image number: 563
# Preparing image number: 564
# Preparing image number: 565
# Preparing image number: 566
# Preparing image number: 567
# Preparing image number: 568
# Preparing image number: 569
# Preparing image number: 570
# Preparing image number: 571
# Preparing image number: 572
# Preparing image number: 573
# Preparing image number: 574
# Preparing image number: 575
# Preparing image number: 576
# Preparing image number: 577
# Preparing image number: 578
# Preparing image number: 579
# Preparing image number: 580
# Preparing image number: 581
# Preparing image number: 582
# Preparing image number: 583
# Preparing image number: 584
# Preparing image number: 585
# Preparing image number: 586
# Preparing image number: 587
# Preparing image number: 588
# Preparing image number: 589
# Preparing image number: 590
# Preparing image number: 591
# Preparing image number: 592
# Preparing image number: 593
# Preparing image number: 594
# Preparing image number: 595
# Preparing image number: 596
# Preparing image number: 597
# Preparing image number: 598
# Preparing image number: 599
# Preparing image number: 600
# Preparing image number: 601
# Preparing image number: 602
# Preparing image number: 603
# Preparing image number: 604
# Preparing image number: 605
# Preparing image number: 606
# Preparing image number: 607
# Preparing image number: 608
# Preparing image number: 609
# Preparing image number: 610
# Preparing image number: 611
# Preparing image number: 612
# Preparing image number: 613
# Preparing image number: 614
# Preparing image number: 615
# Preparing image number: 616
# Preparing image number: 617
# Preparing image number: 618
# Preparing image number: 619
# Preparing image number: 620
# Preparing image number: 621
# Preparing image number: 622
# Preparing image number: 623
# Preparing image number: 624
# Preparing image number: 625
# Preparing image number: 626
# Preparing image number: 627
# Preparing image number: 628
# Preparing image number: 629
# Preparing image number: 630
# Preparing image number: 631
# Preparing image number: 632
# Preparing image number: 633
# Preparing image number: 634
# Preparing image number: 635
# Preparing image number: 636
# Preparing image number: 637
# Preparing image number: 638
# Preparing image number: 639
# Preparing image number: 640
# Preparing image number: 641
# Preparing image number: 642
# Preparing image number: 643
# Preparing image number: 644
# Preparing image number: 645
# Preparing image number: 646
# Preparing image number: 647
# Preparing image number: 648
# Preparing image number: 649
# Preparing image number: 650
# Preparing image number: 651
# Preparing image number: 652
# Preparing image number: 653
# Preparing image number: 654
# Preparing image number: 655
# Preparing image number: 656
# Preparing image number: 657
# Preparing image number: 658
# Preparing image number: 659
# Preparing image number: 660
# Preparing image number: 661
# Preparing image number: 662
# Preparing image number: 663
# Preparing image number: 664
# Preparing image number: 665
# Preparing image number: 666
# Preparing image number: 667
# Preparing image number: 668
# Preparing image number: 669
# Preparing image number: 670
# Preparing image number: 671
# Preparing image number: 672
# Preparing image number: 673
# Preparing image number: 674
# Preparing image number: 675
# Preparing image number: 676
# Preparing image number: 677
# Preparing image number: 678
# Preparing image number: 679
# Preparing image number: 680
# Preparing image number: 681
# Preparing image number: 682
# Preparing image number: 683
# Preparing image number: 684
# Preparing image number: 685
# Preparing image number: 686
# Preparing image number: 687
# Preparing image number: 688
# Preparing image number: 689
# Preparing image number: 690
# Preparing image number: 691
# Preparing image number: 692
# Preparing image number: 693
# Preparing image number: 694
# Preparing image number: 695
# Preparing image number: 696
# Preparing image number: 697
# Preparing image number: 698
# Preparing image number: 699
# Preparing image number: 700
# Preparing image number: 701
# Preparing image number: 702
# Preparing image number: 703
# Preparing image number: 704
# Preparing image number: 705
# Preparing image number: 706
# Preparing image number: 707
# Preparing image number: 708
# Preparing image number: 709
# Preparing image number: 710
# Preparing image number: 711
# Preparing image number: 712
# Preparing image number: 713
# Preparing image number: 714
# Preparing image number: 715
# Preparing image number: 716
# Preparing image number: 717
# Preparing image number: 718
# Preparing image number: 719
# Preparing image number: 720
# Preparing image number: 721
# Preparing image number: 722
# Preparing image number: 723
# Preparing image number: 724
# Preparing image number: 725
# Preparing image number: 726
# Preparing image number: 727
# Preparing image number: 728
# Preparing image number: 729
# Preparing image number: 730
# Preparing image number: 731
# Preparing image number: 732
# Preparing image number: 733
# Preparing image number: 734
# Preparing image number: 735
# Preparing image number: 736
# Preparing image number: 737
# Preparing image number: 738
# Preparing image number: 739
# Preparing image number: 740
# Preparing image number: 741
# Preparing image number: 742
# Preparing image number: 743
# Preparing image number: 744
# Preparing image number: 745
# Preparing image number: 746
# Preparing image number: 747
# Preparing image number: 748
# Preparing image number: 749
# Preparing image number: 750
# Preparing image number: 751
# Preparing image number: 752
# Preparing image number: 753
# Preparing image number: 754
# Preparing image number: 755
# Preparing image number: 756
# Preparing image number: 757
# Preparing image number: 758
# Preparing image number: 759
# Preparing image number: 760
# Preparing image number: 761
# Preparing image number: 762
# Preparing image number: 763
# Preparing image number: 764
# Preparing image number: 765
# Preparing image number: 766
# Preparing image number: 767
# Preparing image number: 768
# Preparing image number: 769
# Preparing image number: 770
# Preparing image number: 771
# Preparing image number: 772
# Preparing image number: 773
# Preparing image number: 774
# Preparing image number: 775
# Preparing image number: 776
# Preparing image number: 777
# Preparing image number: 778
# Preparing image number: 779
# Preparing image number: 780
# Preparing image number: 781
# Preparing image number: 782
# Preparing image number: 783
# Preparing image number: 784
# Preparing image number: 785
# Preparing image number: 786
# Preparing image number: 787
# Preparing image number: 788
# Preparing image number: 789
# Preparing image number: 790
# Preparing image number: 791
# Preparing image number: 792
# Preparing image number: 793
# Preparing image number: 794
# Preparing image number: 795
# Preparing image number: 796
# Preparing image number: 797
# Preparing image number: 798
# Preparing image number: 799
# Preparing image number: 800
# Preparing image number: 801
# Preparing image number: 802
# Preparing image number: 803
# Preparing image number: 804
# Preparing image number: 805
# Preparing image number: 806
# Preparing image number: 807
# Preparing image number: 808
# Preparing image number: 809
# Preparing image number: 810
# Preparing image number: 811
# Preparing image number: 812
# Preparing image number: 813
# Preparing image number: 814
# Preparing image number: 815
# Preparing image number: 816
# Preparing image number: 817
# Preparing image number: 818
# Preparing image number: 819
# Preparing image number: 820
# Preparing image number: 821
# Preparing image number: 822
# Preparing image number: 823
# Preparing image number: 824
# Preparing image number: 825
# Preparing image number: 826
# Preparing image number: 827
# Preparing image number: 828
# Preparing image number: 829
# Preparing image number: 830
# Preparing image number: 831
# Preparing image number: 832
# Preparing image number: 833
# Preparing image number: 834
# Preparing image number: 835
# Preparing image number: 836
# Preparing image number: 837
# Preparing image number: 838
# Preparing image number: 839
# Preparing image number: 840
# Preparing image number: 841
# Preparing image number: 842
# Preparing image number: 843
# Preparing image number: 844
# Preparing image number: 845
# Preparing image number: 846
# Preparing image number: 847
# Preparing image number: 848
# Preparing image number: 849
# Preparing image number: 850
# Preparing image number: 851
# Preparing image number: 852
# Preparing image number: 853
# Preparing image number: 854
# Preparing image number: 855
# Preparing image number: 856
# Preparing image number: 857
# Preparing image number: 858
# Preparing image number: 859
# Preparing image number: 860
# Preparing image number: 861
# Preparing image number: 862
# Preparing image number: 863
# Preparing image number: 864
# Preparing image number: 865
# Preparing image number: 866
# Preparing image number: 867
# Preparing image number: 868
# Preparing image number: 869
# Preparing image number: 870
# Preparing image number: 871
# Preparing image number: 872
# Preparing image number: 873
# Preparing image number: 874
# Preparing image number: 875
# Preparing image number: 876
# Preparing image number: 877
# Preparing image number: 878
# Preparing image number: 879
# Preparing image number: 880
# Preparing image number: 881
# Preparing image number: 882
# Preparing image number: 883
# Preparing image number: 884
# Preparing image number: 885
# Preparing image number: 886
# Preparing image number: 887
# Preparing image number: 888
# Preparing image number: 889
# Preparing image number: 890
# Preparing image number: 891
# Preparing image number: 892
# Preparing image number: 893
# Preparing image number: 894
# Preparing image number: 895
# Preparing image number: 896
# Preparing image number: 897
# Preparing image number: 898
# Preparing image number: 899
# Preparing image number: 900
# Preparing image number: 901
# Preparing image number: 902
# Preparing image number: 903
# Preparing image number: 904
# Preparing image number: 905
# Preparing image number: 906
# Preparing image number: 907
# Preparing image number: 908
# Preparing image number: 909
# Preparing image number: 910
# Preparing image number: 911
# Preparing image number: 912
# Preparing image number: 913
# Preparing image number: 914
# Preparing image number: 915
# Preparing image number: 916
# Preparing image number: 917
# Preparing image number: 918
# Preparing image number: 919
# Preparing image number: 920
# Preparing image number: 921
# Preparing image number: 922
# Preparing image number: 923
# Preparing image number: 924
# Preparing image number: 925
# Preparing image number: 926
# Preparing image number: 927
# Preparing image number: 928
# Preparing image number: 929
# Preparing image number: 930
# Preparing image number: 931
# Preparing image number: 932
# Preparing image number: 933
# Preparing image number: 934
# Preparing image number: 935
# Preparing image number: 936
# Preparing image number: 937
# Preparing image number: 938
# Preparing image number: 939
# Preparing image number: 940
# Preparing image number: 941
# Preparing image number: 942
# Preparing image number: 943
# Preparing image number: 944
# Preparing image number: 945
# Preparing image number: 946
# Preparing image number: 947
# Preparing image number: 948
# Preparing image number: 949
# Preparing image number: 950
# Preparing image number: 951
# Preparing image number: 952
# Preparing image number: 953
# Preparing image number: 954
# Preparing image number: 955
# Preparing image number: 956
# Preparing image number: 957
# Preparing image number: 958
# Preparing image number: 959
# Preparing image number: 960
# Preparing image number: 961
# Preparing image number: 962
# Preparing image number: 963
# Preparing image number: 964
# Preparing image number: 965
# Preparing image number: 966
# Preparing image number: 967
# Preparing image number: 968
# Preparing image number: 969
# Preparing image number: 970
# Preparing image number: 971
# Preparing image number: 972
# Preparing image number: 973
# Preparing image number: 974
# Preparing image number: 975
# Preparing image number: 976
# Preparing image number: 977
# Preparing image number: 978
# Preparing image number: 979
# Preparing image number: 980
# Preparing image number: 981
# Preparing image number: 982
# Preparing image number: 983
# Preparing image number: 984
# Preparing image number: 985
# Preparing image number: 986
# Preparing image number: 987
# Preparing image number: 988
# Preparing image number: 989
# Preparing image number: 990
# Preparing image number: 991
# Preparing image number: 992
# Preparing image number: 993
# Preparing image number: 994
# Preparing image number: 995
# Preparing image number: 996
# Preparing image number: 997
# Preparing image number: 998
# Preparing image number: 999
# Preparing image number: 1000
# Preparing image number: 1001
# Preparing image number: 1002
# Preparing image number: 1003
# Preparing image number: 1004
# Preparing image number: 1005
# Preparing image number: 1006
# Preparing image number: 1007
# Preparing image number: 1008
# Preparing image number: 1009
# Preparing image number: 1010
# Preparing image number: 1011
# Preparing image number: 1012
# Preparing image number: 1013
# Preparing image number: 1014
# Preparing image number: 1015
# Preparing image number: 1016
# Preparing image number: 1017
# Preparing image number: 1018
# Preparing image number: 1019
# Preparing image number: 1020
# Preparing image number: 1021
# Preparing image number: 1022
# Preparing image number: 1023
# Preparing image number: 1024
# Preparing image number: 1025
# Preparing image number: 1026
# Preparing image number: 1027
# Preparing image number: 1028
# Preparing image number: 1029
# Preparing image number: 1030
# Preparing image number: 1031
# Preparing image number: 1032
# Preparing image number: 1033
# Preparing image number: 1034
# Preparing image number: 1035
# Preparing image number: 1036
# Preparing image number: 1037
# Preparing image number: 1038
# Preparing image number: 1039
# Preparing image number: 1040
# Preparing image number: 1041
# Preparing image number: 1042
# Preparing image number: 1043
# Preparing image number: 1044
# Preparing image number: 1045
# Preparing image number: 1046
# Preparing image number: 1047
# Preparing image number: 1048
# Preparing image number: 1049
# Preparing image number: 1050
# Preparing image number: 1051
# Preparing image number: 1052
# Preparing image number: 1053
# Preparing image number: 1054
# Preparing image number: 1055
# Preparing image number: 1056
# Preparing image number: 1057
# Preparing image number: 1058
# Preparing image number: 1059
# Preparing image number: 1060
# Preparing image number: 1061
# Preparing image number: 1062
# Preparing image number: 1063
# Preparing image number: 1064
# Preparing image number: 1065
# Preparing image number: 1066
# Preparing image number: 1067
# Preparing image number: 1068
# Preparing image number: 1069
# Preparing image number: 1070
# Preparing image number: 1071
# Preparing image number: 1072
# Preparing image number: 1073
# Preparing image number: 1074
# Preparing image number: 1075
# Preparing image number: 1076
# Preparing image number: 1077
# Preparing image number: 1078
# Preparing image number: 1079
# Preparing image number: 1080
# Preparing image number: 1081
# Preparing image number: 1082
# Preparing image number: 1083
# Preparing image number: 1084
# Preparing image number: 1085
# Preparing image number: 1086
# Preparing image number: 1087
# Preparing image number: 1088
# Preparing image number: 1089
# Preparing image number: 1090
# Preparing image number: 1091
# Preparing image number: 1092
# Preparing image number: 1093
# Preparing image number: 1094
# Preparing image number: 1095
# Preparing image number: 1096
# Preparing image number: 1097
# Preparing image number: 1098
# Preparing image number: 1099
# Preparing image number: 1100
# Preparing image number: 1101
# Preparing image number: 1102
# Preparing image number: 1103
# Preparing image number: 1104
# Preparing image number: 1105
# Preparing image number: 1106
# Preparing image number: 1107
# Preparing image number: 1108
# Preparing image number: 1109
# Preparing image number: 1110
# Preparing image number: 1111
# Preparing image number: 1112
# Preparing image number: 1113
# Preparing image number: 1114
# Preparing image number: 1115
# Preparing image number: 1116
# Preparing image number: 1117
# Preparing image number: 1118
# Preparing image number: 1119
# Preparing image number: 1120
# Preparing image number: 1121
# Preparing image number: 1122
# Preparing image number: 1123
# Preparing image number: 1124
# Preparing image number: 1125
# Preparing image number: 1126
# Preparing image number: 1127
# Preparing image number: 1128
# Preparing image number: 1129
# Preparing image number: 1130
# Preparing image number: 1131
# Preparing image number: 1132
# Preparing image number: 1133
# Preparing image number: 1134
# Preparing image number: 1135
# Preparing image number: 1136
# Preparing image number: 1137
# Preparing image number: 1138
# Preparing image number: 1139
# Preparing image number: 1140
# Preparing image number: 1141
# Preparing image number: 1142
# Preparing image number: 1143
# Preparing image number: 1144
# Preparing image number: 1145
# Preparing image number: 1146
# Preparing image number: 1147
# Preparing image number: 1148
# Preparing image number: 1149
# Preparing image number: 1150
# Preparing image number: 1151
# Preparing image number: 1152
# Preparing image number: 1153
# Preparing image number: 1154
# Preparing image number: 1155
# Preparing image number: 1156
# Preparing image number: 1157
# Preparing image number: 1158
# Preparing image number: 1159
# Preparing image number: 1160
# Preparing image number: 1161
# Preparing image number: 1162
# Preparing image number: 1163
# Preparing image number: 1164
# Preparing image number: 1165
# Preparing image number: 1166
# Preparing image number: 1167
# Preparing image number: 1168
# Preparing image number: 1169
# Preparing image number: 1170
# Preparing image number: 1171
# Preparing image number: 1172
# Preparing image number: 1173
# Preparing image number: 1174
# Preparing image number: 1175
# Preparing image number: 1176
# Preparing image number: 1177
# Preparing image number: 1178
# Preparing image number: 1179
# Preparing image number: 1180
# Preparing image number: 1181
# Preparing image number: 1182
# Preparing image number: 1183
# Preparing image number: 1184
# Preparing image number: 1185
# Preparing image number: 1186
# Preparing image number: 1187
# Preparing image number: 1188
# Preparing image number: 1189
# Preparing image number: 1190
# Preparing image number: 1191
# Preparing image number: 1192
# Preparing image number: 1193
# Preparing image number: 1194
# Preparing image number: 1195
# Preparing image number: 1196
# Preparing image number: 1197
# Preparing image number: 1198
# Preparing image number: 1199
# Preparing image number: 1200
# Preparing image number: 1201
# Preparing image number: 1202
# Preparing image number: 1203
# Preparing image number: 1204
# Preparing image number: 1205
# Preparing image number: 1206
# Preparing image number: 1207
# Preparing image number: 1208
# Preparing image number: 1209
# Preparing image number: 1210
# Preparing image number: 1211
# Preparing image number: 1212
# Preparing image number: 1213
# Preparing image number: 1214
# Preparing image number: 1215
# Preparing image number: 1216
# Preparing image number: 1217
# Preparing image number: 1218
# Preparing image number: 1219
# Preparing image number: 1220
# Preparing image number: 1221
# Preparing image number: 1222
# Preparing image number: 1223
# Preparing image number: 1224
# Preparing image number: 1225
# Preparing image number: 1226
# Preparing image number: 1227
# Preparing image number: 1228
# Preparing image number: 1229
# Preparing image number: 1230
# Preparing image number: 1231
# Preparing image number: 1232
# Preparing image number: 1233
# Preparing image number: 1234
# Preparing image number: 1235
# Preparing image number: 1236
# Preparing image number: 1237
# Preparing image number: 1238
# Preparing image number: 1239
# Preparing image number: 1240
# Preparing image number: 1241
# Preparing image number: 1242
# Preparing image number: 1243
# Preparing image number: 1244

# %%
train_and_test_ResNet50(training_loader, testing_loader, device, num_classes)

# %%
train_and_test_ResNet152(training_loader, testing_loader, device, num_classes)

# %%
train_and_test_ViT_L_16(training_loader, testing_loader, device, num_classes)
